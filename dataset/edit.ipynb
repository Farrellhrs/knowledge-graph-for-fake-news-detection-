# %%
import pandas as pd

# %%
path = r'D:\farrell2\Fake News Politifact\dataset\dataset_sunda_malay__filtered_46k_no_dup.csv'
df = pd.read_csv(path)

# add 'id' column starting from 0
df.insert(0, 'id', range(len(df)))

# show result
df.head()
# Out:
#    id                                           Fulltext  label
# 0   0  Sertifikat Halal Produk McDonald’s Dicabut di ...      1
# 1   1  Tautan Pendaftaran “Rekrutmen Program Literasi...      1
# 2   2  Video “Candi Borobudur Bakal Dipasang Eskalato...      1
# 3   3    Tautan Pendaftaran “Bantuan untuk Guru Honorer”      1
# 4   4            Oey Hong Liong Adalah Nama Kecil Jokowi      1

# %%
# overwrite the original CSV with the current dataframe
df.to_csv(path, index=False)
